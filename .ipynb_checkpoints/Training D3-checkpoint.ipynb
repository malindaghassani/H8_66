# %% [markdown]
# # PYTHON FUNCTION

# %%
# def "nama_dari_function"(parameter) : 
## (statement)

# %%
def nama_dari_function(parameter):
    "mulai dari disini"
    print ("functionnya sudah oke")

# %%
nama_dari_function
# Out:
# <function __main__.nama_dari_function(parameter)>

# %%
def my_function (p,l):
    "Function untuk menghitung luas"
    print(p*l)
    print (p**2)
    print (l**3)

# %%
my_function(2,4)
# Out:
# 8
# 4
# 64

# %%
def printme (str):
    "This prints a passed string into this function"
    print (str)
    return

# %%
printme ("ini yang aku print")
# Out:
# ini yang aku print

# %% [markdown]
# # Calling a Function

# %%
def printme (str):
    "This prints a passed string into this function"
    print (str)
    return;
printme ("I'm first call to user defined function!")
printme ("again second call to the same funcion")
# Out:
# I'm first call to user defined function!
# again second call to the same funcion

# %% [markdown]
# # Pass by references vs Value

# %%
def changeme (mylist):
    "This changes a passed list into this function"
    
    #mylist=[]
    
    
    mylist.append([1,2,3,4]);
    print("value inside the function:",mylist)
    return

## mylist.append = menambahkan (add) list baru di depan
## tidak di define parameternya (mylist = mylist)

# %%
mylist =[10,20,30];
changeme (mylist);
print("value outside the function:",mylist)
# Out:
# value inside the function: [10, 20, 30, [1, 2, 3, 4]]
# value outside the function: [10, 20, 30, [1, 2, 3, 4]]

# %%
# definiskan terlebih dahulu parameternya

def changeme (mylist):
    "This changes a passed list into this function"
    mylist = [1,2,3,4];
    # mylist.append([100,200,300,400]);
    print("value inside the function:",mylist)
    return

mylist = [10,20,30];
changeme (mylist);
print("value outside the function:",mylist)
# Out:
# value inside the function: [1, 2, 3, 4]
# value outside the function: [10, 20, 30]

# %%
mylist = [10,20,30]
mylist.extend([1,2,3,4])
mylist
# Out:
# [10, 20, 30, 1, 2, 3, 4]

# %% [markdown]
# # Variable-length argument

# %% [markdown]
# def functionname([formal_args,]*var_arg_tuple):
#     "function_docstring"
#     function_suite
#     return [expression]

# %%
def printinfo(arg1,*vartuple):
    "This prints a variable passed arguments"
    print('Output is:')
    print(arg1)
    
    print('the tuple are')
    
    for var in vartuple:
        print(var)
    return;

printinfo(10)
printinfo(70,60,50,'a')
# Out:
# Output is:
# 10
# the tuple are
# Output is:
# 70
# the tuple are
# 60
# 50
# a

# %% [markdown]
# # Required argunment

# %%
def printme(str):
    "This prints a passed a string into this function"
    print (str)
    return;

print me()
# Out:
#   File "<ipython-input-84-eac02d2744d1>", line 6
#     print me()
#           ^
# SyntaxError: invalid syntax

# %%
def printme(str,arg2,arg3):
    print (str,arg2,arg3)
    return
printme(str='Hactive',arg2=1,arg3=2)
# Out:
# Hactive 1 2

# %%
def printinfo(name,age):
    "This prints a passed info this function"
    print ("Name:", name);
    print("Age:",age)
    return

printinfo(age=4,name="Hacktiv8")
printinfo("Hactiv8",4)
# Out:
# Name: Hacktiv8
# Age: 4
# Name: Hactiv8
# Age: 4

# %% [markdown]
# # Default arguments

# %%
def printinfo(name,age=26):
    print ("Name:", name)
    print("Age:",age)
    return

printinfo("Hactiv8")
printinfo("Hactiv8",50)
# Out:
# Name: Hactiv8
# Age: 26
# Name: Hactiv8
# Age: 50

# %% [markdown]
# # The Anonymous Function

# %%
# function ini disebut anonymous karena tidak di deklarasikan dengan cara sandar dengan menggunakan keyword def

# %%
# lamda[arg1[,arg2,....arg]]:expression

# %%
sum = lambda arg1,arg2: arg1+arg2;

print("Value of total:",sum(10,20))

#atau bisa ditulis
# Out:
# Value of total: 30

# %%
def sum (arg1,arg2):
    #return 
    arg1 + arg2

print("Value of total:",sum(20,20))
# Out:
# Value of total: None

# %% [markdown]
# # Return Statement

# %%
def sum (arg1,arg2):
    total = arg1+arg2
    total2 = total+arg1
    print("Inside the function:",total)
    return total2

total = sum(10,20)
print('Oustside the function:',total)
# Out:
# Inside the function: 30
# Oustside the function: 40

# %% [markdown]
# # Scope Variable: Global of Variables vs Local Variable

# %%
#didalam rumus adalah local
#diluar rumus adalah global

# %%
total = 0;
def sum(arg1,arg2):
    total = arg1+arg2;
    print('inside the function local total:',total)
    return total;

#def min():

sum(10,20);
print('outside the function global total:',total)
# Out:
# inside the function local total: 30
# outside the function global total: 0

# %%
jumlahKucing =20
def jumlahHewan():
    jumlahAnjing=30
    return jumlahKucing + jumlahAnjing

def jumlahKelinci():
    return jumlahKucing + jumlahKucing

jumlahHewan()
# Out:
# 50

# %%
jumlahKelinci()
# Out:
# 40

# %% [markdown]
# ##### Python modules dan packages
# ###### keuntungan: simplicity, maintanability, reusability, scooping

# %% [markdown]
# # Python Modules

# %%
s="Hactiv8-PTP Pyhton For Data Science"
a=[100,200,300]

def foo (arg):
    print(f'arg={arg}'')

class Foo:
          pass

# %%
import mod
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\3271117\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-125-18de99490651>", line 1, in <module>
#     import mod
#
#   File "C:\Users\3271117\Desktop\TRAINING PYTHON\mod.py", line 5
#     print(f'arg={arg}'')
#                         ^
# SyntaxError: EOL while scanning string literal

# %%
mod
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-126-35e23e581264> in <module>
# ----> 1 mod
#
# NameError: name 'mod' is not defined

# %% [markdown]
# # The module search path

# %%
import mod

# %% [markdown]
# # Dir() Function

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_11',
#  '_114',
#  '_115',
#  '_116',
#  '_117',
#  '_118',
#  '_119',
#  '_13',
#  '_23',
#  '_44',
#  '_54',
#  '_7',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i100',
#  '_i101',
#  '_i102',
#  '_i103',
#  '_i104',
#  '_i105',
#  '_i106',
#  '_i107',
#  '_i108',
#  '_i109',
#  '_i11',
#  '_i110',
#  '_i111',
#  '_i112',
#  '_i113',
#  '_i114',
#  '_i115',
#  '_i116',
#  '_i117',
#  '_i118',
#  '_i119',
#  '_i12',
#  '_i120',
#  '_i121',
#  '_i122',
#  '_i123',
#  '_i124',
#  '_i125',
#  '_i126',
#  '_i127',
#  '_i128',
#  '_i129',
#  '_i13',
#  '_i130',
#  '_i131',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i39',
#  '_i4',
#  '_i40',
#  '_i41',
#  '_i42',
#  '_i43',
#  '_i44',
#  '_i45',
#  '_i46',
#  '_i47',
#  '_i48',
#  '_i49',
#  '_i5',
#  '_i50',
#  '_i51',
#  '_i52',
#  '_i53',
#  '_i54',
#  '_i55',
#  '_i56',
#  '_i57',
#  '_i58',
#  '_i59',
#  '_i6',
#  '_i60',
#  '_i61',
#  '_i62',
#  '_i63',
#  '_i64',
#  '_i65',
#  '_i66',
#  '_i67',
#  '_i68',
#  '_i69',
#  '_i7',
#  '_i70',
#  '_i71',
#  '_i72',
#  '_i73',
#  '_i74',
#  '_i75',
#  '_i76',
#  '_i77',
#  '_i78',
#  '_i79',
#  '_i8',
#  '_i80',
#  '_i81',
#  '_i82',
#  '_i83',
#  '_i84',
#  '_i85',
#  '_i86',
#  '_i87',
#  '_i88',
#  '_i89',
#  '_i9',
#  '_i90',
#  '_i91',
#  '_i92',
#  '_i93',
#  '_i94',
#  '_i95',
#  '_i96',
#  '_i97',
#  '_i98',
#  '_i99',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'changeme',
#  'exit',
#  'get_ipython',
#  'jumlahHewan',
#  'jumlahKelinci',
#  'jumlahKucing',
#  'my_function',
#  'mylist',
#  'nama_dari_function',
#  'nama_function',
#  'printinfo',
#  'printme',
#  'quit',
#  'sum',
#  'total']

# %%
qux = [1,2,3,4,5]

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_11',
#  '_114',
#  '_115',
#  '_116',
#  '_117',
#  '_118',
#  '_119',
#  '_13',
#  '_131',
#  '_132',
#  '_23',
#  '_44',
#  '_54',
#  '_7',
#  '_9',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i100',
#  '_i101',
#  '_i102',
#  '_i103',
#  '_i104',
#  '_i105',
#  '_i106',
#  '_i107',
#  '_i108',
#  '_i109',
#  '_i11',
#  '_i110',
#  '_i111',
#  '_i112',
#  '_i113',
#  '_i114',
#  '_i115',
#  '_i116',
#  '_i117',
#  '_i118',
#  '_i119',
#  '_i12',
#  '_i120',
#  '_i121',
#  '_i122',
#  '_i123',
#  '_i124',
#  '_i125',
#  '_i126',
#  '_i127',
#  '_i128',
#  '_i129',
#  '_i13',
#  '_i130',
#  '_i131',
#  '_i132',
#  '_i133',
#  '_i134',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i39',
#  '_i4',
#  '_i40',
#  '_i41',
#  '_i42',
#  '_i43',
#  '_i44',
#  '_i45',
#  '_i46',
#  '_i47',
#  '_i48',
#  '_i49',
#  '_i5',
#  '_i50',
#  '_i51',
#  '_i52',
#  '_i53',
#  '_i54',
#  '_i55',
#  '_i56',
#  '_i57',
#  '_i58',
#  '_i59',
#  '_i6',
#  '_i60',
#  '_i61',
#  '_i62',
#  '_i63',
#  '_i64',
#  '_i65',
#  '_i66',
#  '_i67',
#  '_i68',
#  '_i69',
#  '_i7',
#  '_i70',
#  '_i71',
#  '_i72',
#  '_i73',
#  '_i74',
#  '_i75',
#  '_i76',
#  '_i77',
#  '_i78',
#  '_i79',
#  '_i8',
#  '_i80',
#  '_i81',
#  '_i82',
#  '_i83',
#  '_i84',
#  '_i85',
#  '_i86',
#  '_i87',
#  '_i88',
#  '_i89',
#  '_i9',
#  '_i90',
#  '_i91',
#  '_i92',
#  '_i93',
#  '_i94',
#  '_i95',
#  '_i96',
#  '_i97',
#  '_i98',
#  '_i99',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'changeme',
#  'exit',
#  'get_ipython',
#  'jumlahHewan',
#  'jumlahKelinci',
#  'jumlahKucing',
#  'my_function',
#  'mylist',
#  'nama_dari_function',
#  'nama_function',
#  'printinfo',
#  'printme',
#  'quit',
#  'qux',
#  'sum',
#  'total']

# %%
import mod
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\3271117\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-135-18de99490651>", line 1, in <module>
#     import mod
#
#   File "C:\Users\3271117\Desktop\TRAINING PYTHON\mod.py", line 5
#     print(f'arg={arg}'')
#                         ^
# SyntaxError: EOL while scanning string literal

# %%
dir (mod)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-136-59cd388141c9> in <module>
# ----> 1 dir (mod)
#
# NameError: name 'mod' is not defined

# %%
import mod

# %%
print(mod.s)
# Out:
# Hactiv8-PTP Python For Data Science

# %%
mod.a
# Out:
# [100, 200, 300]

# %%
mod.foo(['quux','corge','grault'])
# Out:
# arg = ['quux', 'corge', 'grault']

# %%
x=mod.Foo()

# %%
import sys

# %%
sys.path
# Out:
# ['C:\\Users\\3271117\\Desktop\\TRAINING PYTHON',
#  'C:\\Users\\3271117\\Anaconda3\\python38.zip',
#  'C:\\Users\\3271117\\Anaconda3\\DLLs',
#  'C:\\Users\\3271117\\Anaconda3\\lib',
#  'C:\\Users\\3271117\\Anaconda3',
#  '',
#  'C:\\Users\\3271117\\Anaconda3\\lib\\site-packages',
#  'C:\\Users\\3271117\\Anaconda3\\lib\\site-packages\\locket-0.2.1-py3.8.egg',
#  'C:\\Users\\3271117\\Anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\3271117\\Anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\3271117\\Anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\3271117\\Anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\3271117\\.ipython']

# %%
import mod

# %%
mod._file_\\Users\\3271117\\Desktop\\TRAINING PYTHON
# Out:
#   File "<ipython-input-14-2013f1c62ef8>", line 1
#     mod._file_\\Users\\3271117\\Desktop\\TRAINING PYTHON
#                                                         ^
# SyntaxError: unexpected character after line continuation character

# %%
a=['foo','bar','baz']

# %%
a
# Out:
# ['foo', 'bar', 'baz']

# %%
from mod import a

# %%
a
# Out:
# [100, 200, 300]

# %%
s = 'foo'

# %%
a=['foo','bar','baz']

# %%
from mod import s as string, a as alist

# %%
s
# Out:
# 'foo'

# %%
string
# Out:
# 'Hactiv8-PTP Python For Data Science'

# %%
a
# Out:
# ['foo', 'bar', 'baz']

# %%
alist
# Out:
# [100, 200, 300]

# %%
import mod as my_module

# %%
my_module.a
# Out:
# [100, 200, 300]

# %%
my_module.foo('qux')
# Out:
# arg = qux

# %%
def bar():
    from mod import foo
    foo('corge')
bar()
# Out:
# arg = corge

# %%
def bar():
    from mod import
# Out:
#   File "<ipython-input-32-f206933e2551>", line 2
#     from mod import
#                    ^
# SyntaxError: invalid syntax
